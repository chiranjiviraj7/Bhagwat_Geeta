# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
adidevananda = pd.read_excel("/content/drive/My Drive/adidevananda_sentiments.xlsx")
adidevananda
# Out:
#      Chapter                                               text  label
# 0          1   Dhritarashtra said On the holy field of Kuruk...      1
# 1          1   Sanjaya said King Duryodhana, on seeing the A...      1
# 2          1   Behold, O teacher, this mighty army of the Pa...      1
# 3          1   There (in that army) are heroes, great bowmen...      1
# 4          1   Dhrstaketu, Cekitana, and the valiant king of...      2
# ..       ...                                                ...    ...
# 696       18   Sanjaya said Thus have I heard this wondrous ...      1
# 697       18   By the grace of Vyasa have I heard this supre...      1
# 698       18   O King, remembering again and again this wond...      1
# 699       18   And remembering over and over again that most...      1
# 700       18   Wherever there is Sri Krishna, the Lord of Yo...      1
#
# [701 rows x 3 columns]

# %%
purohit = pd.read_excel("/content/drive/My Drive/purohit_sentiments.xlsx")

# %%
sivananda = pd.read_excel("/content/drive/My Drive/sivananda_sentiments.xlsx")
gandhi = pd.read_excel("/content/drive/My Drive/gandhi_sentiments.xlsx")

# %%
dicti = {
    0: 'sadness',
    1: 'joy',
    2: 'love',
    3: 'anger',
    4: 'fear',
    5: 'neutral'
}
for i in range(len(purohit['label'])):
  purohit['label'][i] = dicti[purohit['label'][i]]
# Out:
# <ipython-input-6-22de8eee1ae2>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purohit['label'][i] = dicti[purohit['label'][i]]

# %%
for i in range(len(purohit['label'])):
  sivananda['label'][i] = dicti[sivananda['label'][i]]
for i in range(len(purohit['label'])):
  gandhi['label'][i] = dicti[gandhi['label'][i]]
for i in range(len(purohit['label'])):
  adidevananda['label'][i] = dicti[adidevananda['label'][i]]
# Out:
# <ipython-input-7-6685b248f8f0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sivananda['label'][i] = dicti[sivananda['label'][i]]
# <ipython-input-7-6685b248f8f0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gandhi['label'][i] = dicti[gandhi['label'][i]]
# <ipython-input-7-6685b248f8f0>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adidevananda['label'][i] = dicti[adidevananda['label'][i]]

# %%
purohit
# Out:
#      Chapter                                               text    label
# 0          1   The King Dhritarashtra asked: "O Sanjaya! Wha...  sadness
# 1          1   Sanjaya replied: "The Prince Duryodhana, when...     love
# 2          1   Revered Father! Behold this mighty host of th...      joy
# 3          1   In it are heroes and great bowmen; the equals...     love
# 4          1   Dhrishtaketu, Chekitan, the valiant King of B...      joy
# ..       ...                                                ...      ...
# 696       18   Sanjaya told: "Thus have I heard this rare, w...      joy
# 697       18   Through the blessing of the sage Vyasa, I lis...      joy
# 698       18   O King! The more I think of that marvellous a...  sadness
# 699       18   As memory recalls again and again the exceedi...     love
# 700       18   Wherever is the Lord Shri Krishna, the Prince...  sadness
#
# [701 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
value_counts = [adidevananda['label'].value_counts(), purohit['label'].value_counts(), sivananda['label'].value_counts(), gandhi['label'].value_counts()]
result_df = pd.concat(value_counts, axis=1, keys=['adidevananda', 'purohit', 'sivananda', 'gandhi'])
result_df.plot(kind='bar', color=['blue', 'orange', 'green', 'red'])
plt.ylabel('verses')
plt.xlabel('emotions')
# Out:
# Text(0.5, 0, 'emotions')

# %%
import seaborn as sns

# %%
sivananda['author'] = 'sivananda'

# %%
sivananda
# Out:
#      Chapter                                               text    label  \
# 0          1   Dhritarashtra said What did my people and the...      joy
# 1          1   Sanjaya said Having seen the army of the Pand...      joy
# 2          1   "Behold, O Teacher! this mighty army of the s...  sadness
# 3          1   Here are heroes, mighty archers, eal in battl...      joy
# 4          1   "Dhrishtaketu, chekitana and the valiant king...      joy
# ..       ...                                                ...      ...
# 696       18   Sanjaya said Thus I have heard this wonderful...  sadness
# 697       18   Through the grace of Vyasa I have heard this ...      joy
# 698       18   O King, remembering this wonderful and holy d...      joy
# 699       18   And, remembering again and again, also that m...      joy
# 700       18   Wherever is Krishna, the Lord of Yoga; wherev...      joy
#
#         author
# 0    sivananda
# 1    sivananda
# 2    sivananda
# 3    sivananda
# ...

# %%
purohit['author'] = 'purohit'
adidevananda['author'] = 'adidevananda'
gandhi['author'] = 'gandhi'

# %%
adidevananda.to_excel("/content/drive/My Drive/senti_adi.xlsx", index = False)
purohit.to_excel("/content/drive/My Drive/senti_purohit.xlsx", index = False)
gandhi.to_excel("/content/drive/My Drive/senti_gandhi.xlsx", index = False)
sivananda.to_excel("/content/drive/My Drive/senti_siva.xlsx", index = False)

# %%
whole_df = pd.concat([adidevananda, purohit, sivananda, gandhi], axis = 0)
whole_df
whole_df.to_excel("/content/drive/My Drive/senti_all.xlsx", index = False)

# %%
for i in range(1,19):
  value_counts = [adidevananda[adidevananda['Chapter'] == i]['label'].value_counts(),
                  purohit[purohit['Chapter'] == i]['label'].value_counts(),
                  sivananda[sivananda['Chapter'] == i]['label'].value_counts(),
                  gandhi[gandhi['Chapter'] == i]['label'].value_counts()]
  result_df = pd.concat(value_counts, axis=1, keys=['adidevananda', 'purohit', 'sivananda', 'gandhi'])
  result_df.plot(kind='bar', color=['blue', 'orange', 'green', 'red'])
  plt.title(f'Chapter {i}')
  plt.ylabel('verses')
  plt.xlabel('emotions')
  plt.show()

# %%
adidevananda_gandhi_sentiments = adidevananda['label'] == gandhi['label']

# %%
sum(adidevananda_gandhi_sentiments)/len(adidevananda_gandhi_sentiments)
# Out:
# 0.48359486447931527

# %%
purohit_gandhi_sentiments = purohit['label'] == gandhi['label']
sum(purohit_gandhi_sentiments)/len(purohit_gandhi_sentiments)
# Out:
# 0.5092724679029957

# %%
sivananda_gandhi_sentiments = sivananda['label'] == gandhi['label']
sum(sivananda_gandhi_sentiments)/len(sivananda_gandhi_sentiments)
# Out:
# 0.4579172610556348

# %%
adidevananda_purohit_sentiments = adidevananda['label'] == purohit['label']
sum(adidevananda_purohit_sentiments)/len(adidevananda_purohit_sentiments)
# Out:
# 0.4764621968616263

# %%
adidevananda_sivananda_sentiments = adidevananda['label'] == sivananda['label']
sum(adidevananda_sivananda_sentiments)/len(adidevananda_sivananda_sentiments)
# Out:
# 0.4579172610556348

# %%
purohit_sivananda_sentiments = purohit['label'] == sivananda['label']
sum(purohit_sivananda_sentiments)/len(purohit_sivananda_sentiments)
# Out:
# 0.4593437945791726

# %%
adidevananda_gandhi = []
purohit_gandhi = []
sivananda_gandhi = []
purohit_sivananda = []
adidevananda_sivananda = []
adidevananda_purohit = []
for i in range(1,19):
  adidevananda_gandhi.append(sum(adidevananda[adidevananda['Chapter'] == i]['label'] == gandhi[gandhi['Chapter'] == i]['label'])/len(adidevananda[adidevananda['Chapter'] == i]))
  adidevananda_purohit.append(sum(adidevananda[adidevananda['Chapter'] == i]['label'] == purohit[purohit['Chapter'] == i]['label'])/len(adidevananda[adidevananda['Chapter'] == i]))
  adidevananda_sivananda.append(sum(adidevananda[adidevananda['Chapter'] == i]['label'] == sivananda[sivananda['Chapter'] == i]['label'])/len(adidevananda[adidevananda['Chapter'] == i]))
  purohit_sivananda.append(sum(purohit[purohit['Chapter'] == i]['label'] == sivananda[sivananda['Chapter'] == i]['label'])/len(adidevananda[adidevananda['Chapter'] == i]))
  purohit_gandhi.append(sum(purohit[purohit['Chapter'] == i]['label'] == gandhi[gandhi['Chapter'] == i]['label'])/len(adidevananda[adidevananda['Chapter'] == i]))
  sivananda_gandhi.append(sum(sivananda[sivananda['Chapter'] == i]['label'] == gandhi[gandhi['Chapter'] == i]['label'])/len(adidevananda[adidevananda['Chapter'] == i]))

# %%
plt.figure(figsize=(14, 6))
plt.plot([i for i in range (1,19)], adidevananda_purohit, marker='o', linestyle='dotted', label='adidevananda_purohit')
plt.plot([i for i in range (1,19)], adidevananda_sivananda, marker='o', linestyle='dotted', label='adidevananda_sivananda')
plt.plot([i for i in range (1,19)], adidevananda_gandhi, marker='o', linestyle='dotted', label='adidevananda_gandhi')
plt.plot([i for i in range (1,19)], purohit_sivananda, marker='o', linestyle='dotted', label='purohit_sivananda')
plt.plot([i for i in range (1,19)], purohit_gandhi, marker='o', linestyle='dotted', label='purohit_gandhi')
plt.plot([i for i in range (1,19)], sivananda_gandhi, marker='o', linestyle='dotted', label='sivananda_gandhi')
plt.title('Jaccard similarity between authors taken two at a time')
plt.xlabel('chapters')
plt.ylabel('similarity')
plt.legend()
plt.show()
